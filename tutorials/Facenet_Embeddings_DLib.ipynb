# %%
import sys 
sys.path.append('..')

# %%
# %matplotlib inline
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import dlib
import os, pickle
import re
import signal
from models.mtcnn import detect_face

# %%
from scipy import misc

# %% [markdown]
# ## Apply FaceNet to an image
#
# We'll use a pre-trained convolutional neural network on a subset of MS-Celebs-1M dataset (the dataset actually contains 100K celebs at this point).
#
# To generate the embedding we need to do the following steps:
#
# 1. Read an image
# - Detect a face rectangle using Dlib face detector
# - Crop the face, and possibly rotate and stretch it to fit the required dimensions of 160x160.
# - Feed the cropped and aligned face image from the previous step into the network, and obtain the embedding.

# %% [markdown]
# ## Detect face

# %%
sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))
pnet, rnet, onet = detect_face.create_mtcnn(sess, None)
minsize = 20 # minimum size of face
threshold = [ 0.6, 0.7, 0.7 ]  # three steps's threshold
factor = 0.709 # scale factor

# %%
def detect_face_mtcnn(image_path):
    img = mpimg.imread(image_path)
    img = img[:,:,0:3]
    bbs, lms = detect_face.detect_face(img, minsize, pnet, rnet, onet, threshold, factor)
    boxes = []
    landmarks = []
    face_index = 0
    for r in bbs:
        # limit bounding box to image size
        r[0] = np.clip(r[0],0,img.shape[0])
        r[1] = np.clip(r[1],0,img.shape[1])
        r[2] = np.clip(r[2],0,img.shape[0])
        r[3] = np.clip(r[3],0,img.shape[1])
        points = []
        for i in range(5):
            points.append((lms[i][face_index] , lms[i+5][face_index]))
        landmarks.append(points)
        boxes.append((int(r[0]) , int(r[1]) , int(r[2]) , int(r[3])))
        #boxes.append(r[:4].astype(int).tolist())
        face_index += 1
    return boxes, img

# %% [markdown]
# ## Align face

# %%
EXPECT_SIZE = 160
def align_face(img, bb):
    assert isinstance(bb, tuple)
    cropped = img[bb[1]:bb[3],bb[0]:bb[2],:]
    scaled = misc.imresize(cropped, (EXPECT_SIZE, EXPECT_SIZE), interp='bilinear')
    return scaled

# %% [markdown]
# ## Facenet Initialization Functions
#
# https://github.com/davidsandberg/facenet

# %%
from os import path

def load_model(model_dir, model_meta, model_content):
    s = tf.InteractiveSession()
    model_dir_exp = os.path.expanduser(model_dir)
    saver = tf.train.import_meta_graph(os.path.join(model_dir_exp, meta_file))
    saver.restore(tf.get_default_session(), os.path.join(model_dir_exp, ckpt_file))
    tf.get_default_graph().as_graph_def()
    return s

# %%
def get_model_filenames(model_dir):
    files = os.listdir(model_dir)
    meta_files = [s for s in files if s.endswith('.meta')]
    if len(meta_files)==0:
        raise ValueError('No meta file found in the model directory (%s)' % model_dir)
    elif len(meta_files)>1:
        raise ValueError('There should not be more than one meta file in the model directory (%s)' % model_dir)
    meta_file = meta_files[0]
    meta_files = [s for s in files if '.ckpt' in s]
    max_step = -1
    for f in files:
        step_str = re.match(r'(^model-[\w\- ]+.ckpt-(\d+))', f)
        if step_str is not None and len(step_str.groups())>=2:
            step = int(step_str.groups()[1])
            if step > max_step:
                max_step = step
                ckpt_file = step_str.groups()[0]
    return meta_file, ckpt_file

# %% [markdown]
# ## Load Facenet
#
# Pre trained model on MS-Celeb-1M

# %%
model_dir = '../models/facenet'
meta_file, ckpt_file = get_model_filenames(os.path.expanduser(model_dir))
session = load_model(model_dir, meta_file, ckpt_file)

# %%
graph = tf.get_default_graph()
image_batch = graph.get_tensor_by_name("input:0")
phase_train_placeholder = graph.get_tensor_by_name("phase_train:0")
embeddings = graph.get_tensor_by_name("embeddings:0")

# %% [markdown]
# ## Functions for Processing database
#
# Load images in a database, calculate embeddings and save to file.
#
# databse format: folders with name of the person, containing images of this person underneath

# %%
def rep_for_image_path(session, image_path):
    global image_batch, phase_train_placeholder, embeddings
    
    rects, face_orig = detect_face_mtcnn(image_path)
    if len(rects) > 0:
        face = align_face(face_orig, rects[0])
        feed_dict = { 
            image_batch: np.expand_dims(face, 0), 
            phase_train_placeholder: False }
    
        rep = session.run(embeddings, feed_dict=feed_dict)
    else:
        rep = None
    return rep

def reps_for_person(dir_name):
    all = []
    file_names = []

    for fname in os.listdir(dir_name):
        rep = rep_for_image_path(session, dir_name + '/' + fname)
        if rep is not None:
            all.append(rep[0])
            file_names.append(fname)
    return np.array(all), file_names

def load_people_faces(dir_path, person_paths, save_file):
    assert isinstance(person_paths, list)
    result = []
    all_file_names = []
    names = []
    i = 0
    rep_file = save_file + '_reps.npy'
    names_file = save_file + '_names.npy'
    print(rep_file, flush=True)
    if(os.path.exists(names_file) and os.path.exists(rep_file)):
        result = np.load(rep_file).tolist()
        names = np.load(names_file)
        i = len(result)
    for person_path in person_paths:
        if person_path in names:
            continue
        if(i%100 == 0):
            np.save(save_file + '_reps', result)
            np.save(save_file + '_names', person_paths[:i] )
        full_path = dir_path + '/' + person_path
        #print(full_path, flush=True)
        reps, file_names = reps_for_person(full_path)
        #print(len(reps), flush=True)
        print('Person ' + person_path + ' done.', flush=True)
        result.append(reps)
        all_file_names.append(file_names)
        i = i+1
    np.save(save_file + '_reps', result)
    np.save(save_file + '_names', person_paths[:i] )

def get_person_list(dir_name):
    return os.listdir(dir_name)

# %% [markdown]
# ## Process Database

# %% [markdown]
# Define paths

# %%
database_path = '../datasets/lfw'
save_path = '../models/lfw_embeddings/new'

# %% [markdown]
# Get all folder names of persons contained in the dataset and then process all images. Save result to save_path.

# %%
names = get_person_list(database_path)
load_people_faces(database_path, names, save_path)
# Out:
# ../models/lfw_embeddings/new_reps.npy
# Person Alberta_Lee done.
# Person Alberto_Acosta done.
# Person Alberto_Fujimori done.
# Person Alberto_Gonzales done.
# Person Alberto_Ruiz_Gallardon done.
# Person Alberto_Sordi done.
# Person Albert_Brooks done.
# Person Albert_Costa done.
# Person Albert_Montanes done.
# Person Albert_Pujols done.
# Person Albrecht_Mentz done.
# Person Aldo_Paredes done.
# Person Alecos_Markides done.
# Person Alec_Baldwin done.
# Person Alejandro_Atchugarry done.
# Person Alejandro_Avila done.
# Person Alejandro_Fernandez done.
# Person Alejandro_Gonzalez_Inarritu done.
# Person Alejandro_Lembo done.
# Person Alejandro_Lerner done.
# Person Alejandro_Lopez done.
# Person Alejandro_Toledo done.
# Person Aleksander_Kwasniewski done.
# Person Aleksander_Voloshin done.
# Person Alek_Wek done.
# Person Alessandra_Cerna done.
# Person Alessandro_Nesta done.
# Person Alexander_Downer done.
# Person Alexander_Losyukov done.
# Person Alexander_Lukashenko done.
# Person Alexander_Payne done.
# Person Alexander_Rumyantsev done.
# Person Alexandra_Jackson done.
# Person Alexandra_Pelosi done.
# Person Alexandra_Rozovskaya done.
# Person Alexandra_Spann done.
# Person Alexandra_Stevenson done.
# Person Alexandra_Vodjanikova done.
# Person Alexandre_Daigle done.
# Person Alexandre_Despatie done.
# Person Alexandre_Herchcovitch done.
# Person Alexandre_Vinokourov done.
# Person Alexa_Loren done.
# Person Alexa_Vega done.
# Person Alexis_Bledel done.
# Person Alexis_Dennisoff done.
# Person Alex_Barros done.
# Person Alex_Cabrera done.
# Person Alex_Cejka done.
# Person Alex_Corretja done.
# Person Alex_Ferguson done.
# Person Alex_Gonzalez done.
# Person Alex_Holmes done.
# Person Alex_King done.
# Person Alex_Penelas done.
# Person Alex_Popov done.
# Person Alex_Sink done.
# Person Alex_Wallau done.
# Person Alex_Zanardi done.
# Person Alfonso_Cuaron done.
# Person Alfonso_Portillo done.
# Person Alfonso_Soriano done.
# Person Alfredo_di_Stefano done.
# Person Alfredo_Moreno done.
# Person Alfredo_Pena done.
# Person Alfred_Ford done.
# Person Alfred_Sant done.
# Person Alice_Fisher done.
# Person Alicia_Hollowell done.
# Person Alicia_Keys done.
# Person Alicia_Molik done.
# Person Alicia_Silverstone done.
# Person Alicia_Witt done.
# Person Alimzhan_Tokhtakhounov done.
# Person Alina_Kabaeva done.
# Person Aline_Chretien done.
# Person Alisha_Richman done.
# Person Alison_Krauss done.
# Person Alison_Lohman done.
# Person Alistair_MacDonald done.
# Person Ali_Abbas done.
# Person Ali_Abdullah_Saleh done.
# Person Ali_Adbul_Karim_Madani done.
# Person Ali_Ahmeti done.
# Person Ali_Bin_Hussein done.
# Person Ali_Fallahian done.
# Person Ali_Hammoud done.
# Person Ali_Khamenei done.
# Person Ali_Mohammed_Maher done.
# Person Ali_Naimi done.
# Person Allan_Houston done.
# Person Allan_Kemakeza done.
# Person Allan_Wagner done.
# Person Allen_Iverson done.
# Person Allen_Rock done.
# Person Allison_Janney done.
# Person Allison_Searing done.
# Person Allyson_Felix done.
# Person Ally_Sheedy done.
# Person Alma_Powell done.
# Person Almeida_Baptista done.
# Person Alonzo_Mourning done.
# Person Alvaro_Noboa done.
# Person Alvaro_Silva_Calderon done.
# Person Alvaro_Uribe done.
# Person Alyse_Beaupre done.
# Person Alyson_Hannigan done.
# Person Aly_Wagner done.
# Person Al_Cardenas done.
# Person Al_Davis done.
# Person Al_Gore done.
# Person Al_Leiter done.
# Person Al_Pacino done.
# Person Al_Sharpton done.
# Person Amanda_Beard done.
# Person Amanda_Bynes done.
# Person Amanda_Coetzer done.
# Person Amanda_Marsh done.
# Person Amanda_Plumer done.
# Person Amber_Frey done.
# Person Amber_Tamblyn done.
# Person Ambrose_Lee done.
# Person Amelia_Vega done.
# Person Amelie_Mauresmo done.
# Person Amer_al-Saadi done.
# Person Amporn_Falise done.
# Person Amram_Mitzna done.
# Person Amr_Moussa done.
# Person Amy_Brenneman done.
# Person Amy_Cotton done.
# Person Amy_Gale done.
# Person Amy_Pascal done.
# Person Amy_Redford done.
# Person Amy_Smart done.
# Person Amy_Yasbeck done.
# Person Anastasia_Kelesidou done.
# Person Anastasia_Myskina done.
# Person Anatoliy_Kinakh done.
# Person Ana_Claudia_Talancon done.
# Person Ana_Guevara done.
# Person Ana_Isabel_Sanchez done.
# Person Ana_Palacio done.
# Person Ana_Paula_Gerard done.
# Person Ana_Sebastiao done.
# Person Anderson_Varejao done.
# Person Anders_Ebbeson done.
# Person Anders_Fogh_Rasmussen done.
# Person Andreas_Vinciguerra done.
# Person Andrea_Bocelli done.
# Person Andrea_De_Cruz done.
# Person Andrea_Kiser done.
# Person Andrea_Yates done.
# Person Andrei_Konchalovsky done.
# Person Andrei_Mikhnevich done.
# Person Andrei_Nikolishin done.
# Person Andres_DAlessandro done.
# Person Andres_Manuel_Lopez_Obrador done.
# Person Andres_Pastrana done.
# Person Andrew_Bernard done.
# Person Andrew_Bunner done.
# Person Andrew_Caldecott done.
# Person Andrew_Cuomo done.
# Person Andrew_Fastow done.
# Person Andrew_Firestone done.
# Person Andrew_Gilligan done.
# Person Andrew_Jarecki done.
# Person Andrew_Luster done.
# Person Andrew_Niccol done.
# Person Andrew_Sabey done.
# Person Andrew_Shutley done.
# Person Andrew_Weissmann done.
# Person Andrew_Wetzler done.
# Person Andre_Agassi done.
# Person Andre_Bucher done.
# Person Andre_Lange done.
# Person Andre_Smith done.
# Person Andre_Techine done.
# Person Andrzej_Tyszkiewicz done.
# Person Andy_Benes done.
# Person Andy_Bryant done.
# Person Andy_Dick done.
# Person Andy_Garcia done.
# Person Andy_Graves done.
# Person Andy_Griffith done.
# Person Andy_Griggs done.
# Person Andy_Hebb done.
# Person Andy_Lau done.
# Person Andy_Madikians done.
# Person Andy_North done.
# Person Andy_Perez done.
# Person Andy_Roddick done.
# Person Andy_Rooney done.
# Person Andy_Warhol done.
# Person Andy_Wisecarver done.
# Person Anette_Hosoi done.
# Person AnFernce_Negron done.
# Person Angela_Alvarado_Rosa done.
# Person Angela_Bassett done.
# Person Angela_Lansbury done.
# Person Angela_Mascia-Frye done.
# Person Angela_Merkel done.
# Person Angelica_Romero done.
# Person Angelina_Jolie done.
# Person Angelo_Genova done.
# Person Angelo_Reyes done.
# Person Angel_Lockward done.
# Person Angel_Maza done.
# Person Angie_Arzola done.
# Person Angie_Martinez done.
# Person Anibal_Ibarra done.
# Person Anil_Ramsook done.
# Person Anita_DeFrantz done.
# Person Anja_Paerson done.
# Person Anjum_Hussain done.
# Person Anna_Chicherova done.
# Person Anna_Faris done.
# Person Anna_Jones done.
# Person Anna_Kournikova done.
# Person Anna_Nicole_Smith done.
# Person Anneli_Jaatteenmaki done.
# Person Annette_Bening done.
# Person Annette_Lu done.
# Person Anne_Cavers done.
# Person Anne_Donovan done.
# Person Anne_Heche done.
# Person Anne_Krueger done.
# Person Anne_McLellan done.
# Person Anne_ONeil done.
# Person Annie-Jeanne_Reynaud done.
# Person Annie_Chaplin done.
# Person Annie_Machon done.
# Person Annika_Sorenstam done.
# Person Ann_Godbehere done.
# Person Ann_Landers done.
# Person Ann_Morgan done.
# Person Ann_Veneman done.
# Person Antanas_Valionis done.
# Person Anthony_Carter done.
# Person Anthony_Corso done.
# Person Anthony_Ervin done.
# Person Anthony_Fauci done.
# Person Anthony_Garotinho done.
# Person Anthony_Hazen done.
# Person Anthony_Hopkins done.
# Person Anthony_LaPaglia done.
# Person Anthony_Lee_Johnson done.
# Person Anthony_Mazur done.
# Person Anthony_Pico done.
# Person Anthony_Pisciotti done.
# Person Anthony_Principi done.
# Person Anthony_Rackauckas done.
# Person Anthony_Scott_Miller done.
# Person Antje_Buschschulte done.
# Person Antonio_Banderas done.
# Person Antonio_Bernardo done.
# Person Antonio_Cassano done.
# Person Antonio_Catania done.
# Person Antonio_Elias_Saca done.
# Person Antonio_Palocci done.
# Person Antonio_Trillanes done.
# Person Antony_Leung done.
# Person Anton_Balasingham done.
# Person Antwun_Echols done.
# Person Anwar_Ibrahim done.
# Person Anzori_Kikalishvili done.
# Person Aparna_Pillai done.
# Person Aram_Adler done.
# Person Arantxa_Sanchez-Vicario done.
# Person Aretha_Franklin done.
# Person Arianna_Huffington done.
# Person Ariel_Sharon done.
# Person Arie_Haan done.
# Person Arif_Mardin done.
# Person Ari_Bousbib done.
# Person Ari_Fleischer done.
# Person Arlen_Specter done.
# Person Armando_Avila_Panchame done.
# Person Armando_Calderon_Sol done.
# Person Armando_Carrillo done.
# Person Armand_Sargen done.
# Person Arminio_Fraga done.
# Person Arnaud_Clement done.
# Person Arnaud_Lagardere done.
# Person Arnie_Boehm done.
# Person Arnoldo_Aleman done.
# Person Arnold_Palmer done.
# Person Arnold_Schwarzenegger done.
# Person Arnold_Scott done.
# Person Aron_Ralston done.
# Person Arsinee_Khanjian done.
# Person Arthur_Johnson done.
# Person Arthur_Martinez done.
# Person Artieas_Shanks done.
# Person Arturo_Gatti done.
# Person Art_Cooper done.
# Person Art_Hoffmann done.
# Person Art_Howe done.
# Person Art_Lopez done.
# Person Arye_Mekel done.
# Person Asa_Hutchinson done.
# Person Ascencion_Barajas done.
# Person Ashanti done.
# Person Ashlea_Talbot done.
# Person Ashley_Judd done.
# Person Ashley_Olsen done.
# Person Ashley_Postell done.
# Person Ashraf_Alasmar done.
# Person Ashraf_Ghani done.
# Person Ashton_Kutcher done.
# Person Asif_Ali_Zardari done.
# Person Asif_Hanif done.
# Person Askar_Akayev done.
# Person Asmaa_Assad done.
# Person Assad_Ahmadi done.
# Person Astou_Ndiaye-Diatta done.
# Person Astrid_Betancourt done.
# Person Astrid_Eyzaguirre done.
# Person Atal_Bihari_Vajpayee done.
# Person Ataollah_Mohajerani done.
# Person Atiabet_Ijan_Amabel done.
# Person Atom_Egoyan done.
# Person Atsushi_Sato done.
# Person Audrey_Lacroix done.
# Person Audrey_Sauret done.
# Person Augustin_Calleri done.
# Person Augusto_Pinochet done.
# Person Augusto_Roa_Bastos done.
# Person Aung_San_Suu_Kyi done.
# Person Austin_Kearns done.
# Person Avril_Lavigne done.
# Person Azmi_Bishara done.
# Person Azra_Akin done.
# Person Babe_Ruth done.
# Person Baburam_Bhattari done.
# Person Bak_Chang-Ryun done.
# Person Barbara_Bach done.
# Person Barbara_Becker done.
# Person Barbara_Bodine done.
# Person Barbara_Boxer done.
# Person Barbara_Brezigar done.
# Person Barbara_De_Brun done.
# Person Barbara_Esbin done.
# Person Barbara_Felt-Miller done.
# Person Barbara_Roberts done.
# Person Barbara_Walters done.
# Person Barbora_Strycova done.
# Person Barbra_Streisand done.
# Person Barrett_Jackman done.
# Person Barry_Alvarez done.
# Person Barry_Bonds done.
# Person Barry_Collier done.
# Person Barry_Diller done.
# Person Barry_Ford done.
# Person Barry_Hinson done.
# Person Barry_Nakell done.
# Person Barry_Switzer done.
# Person Barry_Williams done.
# Person Barry_Zito done.
# Person Bartosz_Kizierowski done.
# Person Bart_Freundlich done.
# Person Bart_Hendricks done.
# Person Barzan_al-Tikriti done.
# Person Basdeo_Panday done.
# Person Bashar_Assad done.
# Person Baz_Luhrmann done.
# Person BB_King done.
# Person Beatrice_Dalle done.
# Person Beatriz_Merino done.
# Person Beecher_Ray_Kirby done.
# Person Begum_Khaleda_Zia done.
# Person Bela_Karolyi done.
# Person Benazir_Bhutto done.
# Person Benedita_da_Silva done.
# Person Benicio_Del_Toro done.
# Person Benito_Santiago done.
# Person Benjamin_Bratt done.
# Person Benjamin_Franklin done.
# Person Benjamin_Martinez done.
# Person Benjamin_McKenzie done.
# Person Benjamin_Netanyahu done.
# Person Benjamin_Neulander done.
# Person Ben_Affleck done.
# Person Ben_Betts done.
# Person Ben_Braun done.
# Person Ben_Broussard done.
# Person Ben_Cahoon done.
# Person Ben_Chandler done.
# Person Ben_Cohen done.
# Person Ben_Curtis done.
# Person Ben_Davis done.
# Person Ben_Glisan done.
# Person Ben_Howland done.
# Person Ben_Kingsley done.
# Person Ben_Lee done.
# Person Ben_Stein done.
# Person Ben_Wallace done.
# Person Bernadette_Peters done.
# Person Bernardo_Segura done.
# Person Bernard_Ebbers done.
# Person Bernard_Giraudeau done.
# Person Bernard_Kerik done.
# Person Bernard_Landry done.
# Person Bernard_Law done.
# Person Bernard_Lord done.
# Person Bernard_Siegel done.
# Person Bernice_Wong done.
# Person Bertie_Ahern done.
# Person Bertrand_Bonello done.
# Person Bertrand_Delanoe done.
# Person Beth_Blough done.
# Person Beth_Jones done.
# Person Betsy_Coffin done.
# Person Betsy_Smith done.
# Person Bettina_Rheims done.
# Person Betty_Garrison done.
# Person Betty_Williams done.
# Person Beyonce_Knowles done.
# Person Bianca_Jagger done.
# Person Bijan_Darvish done.
# Person Bijan_Namdar_Zangeneh done.
# Person Bilal_Erdogan done.
# Person Biljana_Plavsic done.
# Person Billy_Andrade done.
# Person Billy_Beane done.
# Person Billy_Bob_Thornton done.
# Person Billy_Boyd done.
# Person Billy_Crawford done.
# Person Billy_Crystal done.
# Person Billy_Donovan done.
# Person Billy_Edelin done.
# Person Billy_Gilman done.
# Person Billy_Graham done.
# Person Billy_Joel done.
# Person Billy_Rork done.
# Person Billy_Sollie done.
# Person Billy_Tibbets done.
# Person Bill_Belichick done.
# Person Bill_Bradley done.
# Person Bill_Butler done.
# Person Bill_Byrne done.
# Person Bill_Callahan done.
# Person Bill_Carmody done.
# Person Bill_Cartwright done.
# Person Bill_Clancy done.
# Person Bill_Clinton done.
# Person Bill_Curry done.
# Person Bill_Doba done.
# Person Bill_Duffey done.
# Person Bill_Elliott done.
# Person Bill_Fennelly done.
# Person Bill_Frist done.
# Person Bill_Gates done.
# Person Bill_Graham done.
# Person Bill_Guerin done.
# Person Bill_Herrion done.
# Person Bill_Hughes done.
# Person Bill_King done.
# Person Bill_Kollar done.
# Person Bill_Kong done.
# Person Bill_Lerach done.
# Person Bill_Maher done.
# Person Bill_Mauldin done.
# Person Bill_McBride done.
# Person Bill_Nelson done.
# Person Bill_OReilly done.
# Person Bill_Parcells done.
# Person Bill_Parsons done.
# Person Bill_Paxton done.
# Person Bill_Pryor done.
# Person Bill_Rainer done.
# Person Bill_Readdy done.
# Person Bill_Richardson done.
# Person Bill_Self done.
# Person Bill_Simon done.
# Person Bill_Sizemore done.
# Person Bill_Stapleton done.
# Person Bill_Stein done.
# Person Bill_Walton done.
# Person Bing_Crosby done.
# Person Binyamin_Ben-Eliezer done.
# Person Bison_Dele done.
# Person Bixente_LIzarazu done.
# Person BJ_Habibie done.
# Person Blas_Ople done.
# Person Blythe_Danner done.
# Person Blythe_Hartley done.
# Person Bobby_Bowden done.
# Person Bobby_Goldwater done.
# Person Bobby_Jackson done.
# Person Bobby_Kielty done.
# Person Bobby_Robson done.
# Person Bobo_Balde done.
# Person Bob_Alper done.
# Person Bob_Beauprez done.
# Person Bob_Bowlsby done.
# Person Bob_Cantrell done.
# Person Bob_Colvin done.
# Person Bob_Crippen done.
# Person Bob_Curtis done.
# Person Bob_Dole done.
# Person Bob_Eskridge done.
# Person Bob_Ferguson done.
# Person Bob_Geldof done.
# Person Bob_Goldman done.
# Person Bob_Graham done.
# Person Bob_Guccione done.
# Person Bob_Hartley done.
# Person Bob_Hayes done.
# Person Bob_Herz done.
# Person Bob_Holden done.
# Person Bob_Hope done.
# Person Bob_Huggins done.
# Person Bob_Iger done.
# Person Bob_Krueger done.
# Person Bob_Melvin done.
# Person Bob_Menendez done.
# Person Bob_Newhart done.
# Person Bob_Petrino done.
# Person Bob_Riley done.
# Person Bob_Stoops done.
# Person Bob_Sulkin done.
# Person Bob_Taft done.
# Person Bob_Wright done.
# Person Bode_Miller done.
# Person Bonnie_Fuller done.
# Person Bonnie_Hunt done.
# Person Bono done.
# Person Boris_Becker done.
# Person Boris_Berezovsky done.
# Person Boris_Henry done.
# Person Boris_Jordan done.
# Person Boris_Trajkovski done.
# Person Boris_Yeltsin done.
# Person Boutros_Boutros_Ghali done.
# Person Bo_Pelini done.
# Person Bo_Ryan done.
# Person Brady_Rodgers done.
# Person Brad_Alexander_Smith done.
# Person Brad_Banks done.
# Person Brad_Brownell done.
# Person Brad_Garrett done.
# Person Brad_Gushue done.
# Person Brad_Johnson done.
# Person Brad_Miller done.
# Person Brad_Pitt done.
# Person Brad_Russ done.
# Person Brad_Smith done.
# Person Brad_Wilk done.
# Person Brajesh_Mishra done.
# Person Brandon_Boyd done.
# Person Brandon_Fails done.
# Person Brandon_Hammond done.
# Person Brandon_Inge done.
# Person Brandon_Jones done.
# Person Brandon_Knight done.
# Person Brandon_Larson done.
# Person Brandon_Lloyd done.
# Person Brandon_Robinson done.
# Person Brandon_Spann done.
# Person Brandon_Webb done.
# Person Branko_Crvenkovski done.
# Person Brawley_King done.
# Person Brendan_Fraser done.
# Person Brendan_Gaughan done.
# Person Brendan_Hansen done.
# Person Brendan_Stai done.
# Person Brenda_Magana done.
# Person Brenda_van_Dam done.
# Person Brenda_Wilson done.
# Person Brennon_Leighton done.
# Person Brent_Coles done.
# Person Brett_Boone done.
# Person Brett_Hawke done.
# Person Brett_Hull done.
# Person Brett_Perry done.
# Person Brian_Billick done.
# Person Brian_Campbell done.
# Person Brian_Cashman done.
# Person Brian_Clemens done.
# Person Brian_Cook done.
# Person Brian_Cowen done.
# Person Brian_De_Palma done.
# Person Brian_Florence done.
# Person Brian_Grazier done.
# Person Brian_Gregory done.
# Person Brian_Griese done.
# Person Brian_Heidik done.
# Person Brian_Henson done.
# Person Brian_Jordan done.
# Person Brian_Kerr done.
# Person Brian_Lara done.
# Person Brian_McIntyre done.
# Person Brian_Meadors done.
# Person Brian_Mulroney done.
# Person Brian_Olson done.
# Person Brian_Pavlich done.
# Person Brian_Scalabrine done.
# Person Brian_Schneider done.
# Person Brian_StPierre done.
# Person Brian_Van_Dusen done.
# Person Brian_Weaver done.
# Person Brian_Wells done.
# Person Brian_Williams done.
# Person Bridgette_Wilson-Sampras done.
# Person Bridget_Fonda done.
# Person Brigitte_Boisselier done.
# Person Britney_Spears done.
# Person Brittany_Snow done.
# Person Brock_Berlin done.
# Person Bronson_Arroyo done.
# Person Brooke_Adams done.
# Person Brooke_Gordon done.
# Person Brooke_Shields done.
# Person Brook_Robinson done.
# Person Bruce_Arena done.
# Person Bruce_Gebhardt done.
# Person Bruce_Lunsford done.
# Person Bruce_Paltrow done.
# Person Bruce_Springsteen done.
# Person Bruce_Van_De_Velde done.
# Person Bruce_Weber done.
# Person Bruce_Willis done.
# Person Bruna_Colosio done.
# Person Bruno_Junquiera done.
# Person Bryant_Young done.
# Person Bryan_Adams done.
# Person Bryan_Chui done.
# Person Bryan_Cooley done.
# Person Bryan_Murray done.
# Person Bryan_Thomas done.
# Person Bryce_Carmine done.
# Person Buck_Rodgers done.
# Person Buddy_Ryan done.
# Person Budd_Schulberg done.
# Person Bud_Selig done.
# Person Buford_Blount done.
# Person Bulent_Ecevit done.
# Person Bustam_A_Zedan_Aljanabi done.
# Person Butch_Davis done.
# Person Buzz_Hargrove done.
# Person Byron_Scott done.
# Person Cabas done.
# Person Caio_Blat done.
# Person Calbert_Cheaney done.
# Person Calista_Flockhart done.
# Person Calvin_Harrison done.
# Person Calvin_Joseph_Coleman done.
# Person Cameron_Diaz done.
# Person Camilla_Parker_Bowles done.
# Person Camille_Colvin done.
# Person Camille_Lewis done.
# Person Camryn_Manheim done.
# Person Candace_Sutton done.
# Person Candice_Beatty done.
# Person Candice_Bergen done.
# Person Candie_Kung done.
# Person Carey_Lowell done.
# Person Carina_Lau_Ka-ling done.
# Person Carin_Koch done.
# Person Cari_Davis done.
# Person Carla_Del_Ponte done.
# Person Carla_Gay_Balingit done.
# Person Carla_Gugino done.
# Person Carla_Moreno done.
# Person Carla_Myers done.
# Person Carla_Sullivan done.
# Person Carla_Tricoli done.
# Person Carlos_Alberto done.
# Person Carlos_Alberto_Parreira done.
# Person Carlos_Arroyo done.
# Person Carlos_Barra done.
# Person Carlos_Barragan done.
# Person Carlos_Beltran done.
# Person Carlos_Bianchi done.
# Person Carlos_De_Abreu done.
# Person Carlos_Fasciolo done.
# Person Carlos_Ghosn done.
# Person Carlos_Iturgaitz done.
# Person Carlos_Juarez done.
# Person Carlos_Lordkipanitse done.
# Person Carlos_Manuel_Pruneda done.
# Person Carlos_Menem done.
# Person Carlos_Mesa done.
# Person Carlos_Moya done.
# Person Carlos_Ortega done.
# Person Carlos_Paternina done.
# Person Carlos_Queiroz done.
# Person Carlos_Quintanilla_Schmidt done.
# Person Carlos_Ruckauf done.
# Person Carlos_Ruiz done.
# Person Carlos_Salinas done.
# Person Carlos_Savedra done.
# Person Carlos_Vives done.
# Person Carlo_Ancelotti done.
# Person Carlo_Azeglio_Ciampi done.
# Person Carlton_Baugh done.
# Person Carlton_Dotson done.
# Person Carly_Fiorina done.
# Person Carly_Gullickson done.
# Person Carl_Levin done.
# Person Carl_Pope done.
# Person Carl_Reiner done.
# Person Carmen_Electra done.
# Person Carolina_Barco done.
# Person Carolina_Kluft done.
# Person Carolina_Moraes done.
# Person Caroline_Dhavernas done.
# Person Caroline_Kennedy done.
# Person Caroline_Link done.
# Person Carolyn_Dawn_Johnson done.
# Person Carolyn_Kuhl done.
# Person Carol_Burnett done.
# Person Carol_Carmody done.
# Person Carol_Moseley_Braun done.
# Person Carol_Niedermayer done.
# Person Carol_Williams done.
# Person Carrie-Anne_Moss done.
# Person Carroll_Weimer done.
# Person Carson_Daly done.
# Person Carson_Palmer done.
# Person Casey_Crowder done.
# Person Casey_Mears done.
# Person Cassandra_Heise done.
# Person Cass_Ballenger done.
# Person Casy_Preslar done.
# Person Cate_Blanchett done.
# Person Catherine_Bell done.
# Person Catherine_Deneuve done.
# Person Catherine_Donkers done.
# Person Catherine_Ndereba done.
# Person Catherine_Woodard done.
# Person Catherine_Zeta-Jones done.
# Person Cathryn_Crawford done.
# Person Cathy_Chisholm done.
# Person Cathy_Cunningham done.
# Person Cathy_Freeman done.
# Person Catriona_Le_May_Doan done.
# Person Cecile_de_France done.
# Person Cecilia_Bolocco done.
# Person Cecilia_Chang done.
# Person Cecilia_Cheung done.
# Person Cedric_Benson done.
# Person Celia_Cruz done.
# Person Celine_Dion done.
# Person Celso_Amorim done.
# Person Celso_Lafer done.
# Person Cemil_Cicek done.
# Person Cesar_Gaviria done.
# Person Cesar_Maia done.
# Person Chadha_Gurinder done.
# Person Chakib_Khelil done.
# Person Chance_Mock done.
# Person Chanda_Rubin done.
# Person Chandrika_Kumaratunga done.
# Person Chang_Dae-whan done.
# Person Chang_Jae_On done.
# Person Chang_Saio-yue done.
# Person Chang_Sang done.
# Person Chang_Tso done.
# Person Chante_Jawan_Mallard done.
# Person Chan_Choi done.
# Person Chan_Gailey done.
# Person Chan_Ho_Park done.
# Person Charla_Moye done.
# Person Charlene_Barshefsky done.
# Person Charles_Bell done.
# Person Charles_Bronson done.
# Person Charles_Chandler_IV done.
# Person Charles_Cope done.
# Person Charles_Grassley done.
# Person Charles_Holzner done.
# Person Charles_Ingram done.
# Person Charles_Kartman done.
# Person Charles_Lebois done.
# Person Charles_Mathews done.
# Person Charles_Moose done.
# Person Charles_Pickering done.
# Person Charles_Pouty done.
# Person Charles_Richardson done.
# Person Charles_Rogers done.
# Person Charles_Schumer done.
# Person Charles_Tannok done.
# Person Charles_Taylor done.
# Person Charley_Armey done.
# Person Charlie_Coles done.
# Person Charlie_Deane done.
# Person Charlie_Garner done.
# Person Charlie_Hunnam done.
# Person Charlie_Sheen done.
# Person Charlie_Williams done.
# Person Charlie_Zaa done.
# Person Charlize_Theron done.
# Person Charlotte_Casiraghi done.
# Person Charlotte_Chambers done.
# Person Charlotte_Church done.
# Person Charlotte_Rampling done.
# Person Charlton_Heston done.
# Person Charmaine_Crooks done.
# Person Chawki_Armali done.
# Person Cha_Yung-gu done.
# Person Chea_Sophara done.
# Person Chelsea_Clinton done.
# Person Chen_Kaige done.
# Person Chen_Liang_Yu done.
# Person Chen_Shui-bian done.
# Person Chen_Tsai-chin done.
# Person Cherie_Blair done.
# Person Cherry_Jones done.
# Person Cheryl_Ford done.
# Person Cheryl_Hines done.
# Person Cheryl_James done.
# Person Cheryl_Little done.
# Person Cheryl_Tiegs done.
# Person Chhouk_Rin done.
# Person Chick_Hearn done.
# Person Chin-Feng_Chen done.
# Person Chin-Hui_Tsao done.
# Person Chip_Burrus done.
# Person Chip_Ganassi done.
# Person Chip_Knight done.
# Person Chistian_Stahl done.
# Person Chita_Rivera done.
# Person Chloe_Sevigny done.
# Person Choi_Sung-hong done.
# Person Choi_Yun-yong done.
# Person Chok_Tong_Goh done.
# Person Cho_Myung-kyun done.
# Person Christiane_Wulff done.
# Person Christian_Bale done.
# Person Christian_Fittipaldi done.
# Person Christian_Gimenez done.
# Person Christian_Lacroix done.
# Person Christian_Lirette done.
# Person Christian_Longo done.
# Person Christian_Malcolm done.
# Person Christian_Olsson done.
# Person Christian_Patino done.
# Person Christian_Von_Wernich done.
# Person Christian_Wulff done.
# Person Christina_Aguilera done.
# Person Christina_Sawaya done.
# Person Christine_Arron done.
# Person Christine_Baumgartner done.
# Person Christine_Ebersole done.
# Person Christine_Gregoire done.
# Person Christine_Rau done.
# Person Christine_Todd_Whitman done.
# Person Christopher_Amolsch done.
# Person Christopher_Conyers done.
# Person Christopher_Matero done.
# Person Christopher_Patten done.
# Person Christopher_Reeve done.
# Person Christopher_Russell done.
# Person Christopher_Speer done.
# Person Christopher_Walken done.
# Person Christopher_Whittle done.
# Person Christoph_Daum done.
# Person Christy_Ferer done.
# Person Christy_Turlington done.
# Person Chris_Andrews done.
# Person Chris_Bell done.
# Person Chris_Byrd done.
# Person Chris_Cirino done.
# Person Chris_Claiborne done.
# Person Chris_Columbus done.
# Person Chris_Cookson done.
# Person Chris_Cooper done.
# Person Chris_Cornell done.
# Person Chris_Crocker done.
# Person Chris_Dodd done.
# Person Chris_Forsyth done.
# Person Chris_Gratton done.
# Person Chris_Hernandez done.
# Person Chris_Klein done.
# Person Chris_Kolanas done.
# Person Chris_Matthews done.
# Person Chris_Moore done.
# Person Chris_Neil done.
# Person Chris_Noth done.
# Person Chris_Penn done.
# Person Chris_Pronger done.
# Person Chris_Reitsma done.
# Person Chris_Rock done.
# Person Chris_Simon done.
# Person Chris_Swecker done.
# Person Chris_Terry done.
# Person Chris_Thomas done.
# Person Chris_Tucker done.
# Person Chris_Whitney done.
# Person Chuanyun_Li done.
# Person Chuck_Amato done.
# Person Chuck_Bednarik done.
# Person Chuck_Eidson done.
# Person Chuck_Finley done.
# Person Chuck_Hagel done.
# Person Chuck_Woolery done.
# Person Chuck_Yeager done.
# Person Chung_Mong-hun done.
# Person Chung_Mong-joon done.
# Person Chyung_Dai-chul done.
# Person Ciaran_Hinds done.
# Person Cindy_Crawford done.
# Person Cindy_Klassen done.
# Person Cindy_Margolis done.
# Person Cindy_Moll done.
# Person Cindy_Taylor done.
# Person Cindy_Zagorski done.
# Person Ciro_Gomes done.
# Person Claire_Danes done.
# Person Claire_De_Gryse done.
# Person Claire_Hentzen done.
# Person Claire_Leger done.
# Person Claire_Tomalin done.
# Person Clara_Harris done.
# Person Clare_Latimer done.
# Person Clare_Short done.
# Person Clark_Randt done.
# Person Claudette_Robinson done.
# Person Claude_Jorda done.
# Person Claudia_Cardinale done.
# Person Claudia_Coslovich done.
# Person Claudia_Pechstein done.
# Person Claudia_Schiffer done.
# Person Claudine_Farrell done.
# Person Claudio_Abbado done.
# Person Claudio_Lopez done.
# Person Claudio_Ranieri done.
# Person Clay_Aiken done.
# Person Clay_Campbell done.
# Person Clemente_de_la_Vega done.
# Person Clifford_Etienne done.
# Person Clifford_Robinson done.
# Person Cliff_Ellis done.
# Person Clint_Eastwood done.
# Person Clint_Howard done.
# Person Clint_Lamebear done.
# Person Clive_Lloyd done.
# Person Clive_Woodward done.
# Person Coco_dEste done.
# Person Coleen_Rowley done.
# Person Cole_Chapman done.
# Person Colin_Campbell done.
# Person Colin_Cowie done.
# Person Colin_Farrell done.
# Person Colin_Jackson done.
# Person Colin_Montgomerie done.
# Person Colin_Phillips done.
# Person Colin_Powell done.
# Person Colin_Prescot done.
# Person Colleen_Atwood done.
# Person Colleen_Donovan done.
# Person Colleen_Jones done.
# Person Colleen_OClair done.
# Person Colleen_Ryan done.
# Person Collis_Temple_III done.
# Person Columba_Bush done.
# Person Compay_Segundo done.
# Person Conan_OBrien done.
# Person Conchita_Martinez done.
# Person Condoleezza_Rice done.
# Person Connie_Chung done.
# Person Connie_Freydell done.
# Person Conrad_Black done.
# Person Constance_Marie done.
# Person Cora_Cambell done.
# Person Coretta_Scott_King done.
# Person Corey_Maggette done.
# Person Corinna_Harfouch done.
# Person Corinne_Coman done.
# Person Cori_Enghusen done.
# Person Corliss_Williamson done.
# Person Cosmo_Iacavazzi done.
# Person Costas_Simitis done.
# Person Courtney_Cox done.
# Person Courtney_Love done.
# Person Craig_Burley done.
# Person Craig_David done.
# Person Craig_Doblin done.
# Person Craig_Fitzgibbon done.
# Person Craig_MacTavish done.
# Person Craig_Morgan done.
# Person Craig_OClair done.
# Person Craig_Wilson done.
# Person Crandall_Bowles done.
# Person Crispin_Glover done.
# Person Cristiano_da_Matta done.
# Person Cristian_Barros done.
# Person Cristina_Fernandez done.
# Person Cristina_Kirchner done.
# Person Cristina_Saralegui done.
# Person Cristina_Torrens_Valero done.
# Person Cruz_Bustamante done.
# Person Cuba_Gooding_Jr done.
# Person Curtis_Joseph done.
# Person Curtis_Rodriguez done.
# Person Curtis_Strange done.
# Person Curt_Weldon done.
# Person Cyndi_Thompson done.
# Person Cynthia_Nixon done.
# Person Cynthia_Rowley done.
# Person Dagmar_Dunlevy done.
# Person Daisy_Fuentes done.
# Person Dai_Bachtiar done.
# Person Dai_Chul_Chyung done.
# Person Daja_Bedanova done.
# Person Dalai_Lama done.
# Person Dale_Bosworth done.
# Person Dale_Earnhardt done.
# Person Dale_Earnhardt_Jr done.
# Person Dalia_Rabin-Pelosoff done.
# Person Damarius_Bilbo done.
# Person Damon_Dash done.
# Person Damon_Stoudamire done.
# Person Damon_van_Dam done.
# Person Dana_Vollmer done.
# Person DAngelo_Jimenez done.
# Person Daniela_Cicarelli done.
# Person Daniela_Hantuchova done.
# Person Daniele_Bergamin done.
# Person Daniele_Hypolito done.
# Person Daniele_Nardello done.
# Person Danielle_Spencer done.
# Person Daniell_Sunjata done.
# Person Daniel_Barenboim done.
# Person Daniel_Bruehl done.
# Person Daniel_Chin done.
# Person Daniel_Coats done.
# Person Daniel_Comisso_Urdaneta done.
# Person Daniel_Darnell done.
# Person Daniel_Day-Lewis done.
# Person Daniel_Kurtzer done.
# Person Daniel_Montenegro done.
# Person Daniel_Montgomery done.
# Person Daniel_Ortega done.
# Person Daniel_Osorno done.
# Person Daniel_Patrick_Moynihan done.
# Person Daniel_Pearl done.
# Person Daniel_Radcliffe done.
# Person Daniel_Rouse done.
# Person Daniel_Scioli done.
# Person Daniel_Zelman done.
# Person Danis_Tanovic done.
# Person Danny_Ainge done.
# Person Danny_Avalon done.
# Person Danny_Elfman done.
# Person Danny_Glover done.
# Person Danny_Green done.
# Person Danny_Morgan done.
# Person Dany_Heatley done.
# Person Dan_Ackroyd done.
# Person Dan_Bartlett done.
# Person Dan_Boyle done.
# Person Dan_Bylsma done.
# Person Dan_Dickau done.
# Person Dan_Duquette done.
# Person Dan_Guerrero done.
# Person Dan_Kellner done.
# Person Dan_LaCoutre done.
# Person Dan_Monson done.
# Person Dan_Morales done.
# Person Dan_Prinster done.
# Person Dan_Quayle done.
# Person Dan_Reeves done.
# Person Dan_Snyder done.
# Person Dan_Wheldon done.
# Person Darcy_Regier done.
# Person Darin_Erstad done.
# Person Dario_Camuffo done.
# Person Dario_Franchitti done.
# Person Dariusz_Michalczewski done.
# Person Darko_Milicic done.
# Person Darla_Moore done.
# Person Darlene_Garrettson done.
# Person Darrell_Dickey done.
# Person Darrell_Issa done.
# Person Darrell_Porter done.
# Person Darrell_Royal done.
# Person Darren_Campel done.
# Person Darren_Clarke done.
# Person Darryl_McDaniels done.
# Person Darryl_Stingley done.
# Person Darvis_Patton done.
# Person Daryl_Hannah done.
# Person Daryl_Jones done.
# Person Daryl_Parks done.
# Person Daryl_Sabara done.
# Person Daryl_Smith done.
# Person Davey_Johnson done.
# Person Dave_Barr done.
# Person Dave_Campo done.
# Person Dave_Johnson done.
# Person Dave_Lewis done.
# Person Dave_Matthews done.
# Person Dave_McGinnis done.
# Person Dave_McNally done.
# Person Dave_McNealey done.
# Person Dave_Odom done.
# Person Dave_Potter done.
# Person Dave_Ragone done.
# Person Dave_Robertson done.
# Person Dave_Tucker done.
# Person Dave_Wannstedt done.
# Person Dave_Williams done.
# Person David_Alpay done.
# Person David_Anderson done.
# Person David_Arquette done.
# Person David_Ballantyne done.
# Person David_Beckham done.
# Person David_Bell done.
# Person David_Bisbal done.
# Person David_Blaine done.
# Person David_Bowie done.
# Person David_Braley done.
# Person David_Brent done.
# Person David_Brinkley done.
# Person David_Brown done.
# Person David_Canary done.
# Person David_Caraway done.
# Person David_Carradine done.
# Person David_Caruso done.
# Person David_Chase done.
# Person David_Collenette done.
# Person David_Coulthard done.
# Person David_Dewayne_Williams done.
# Person David_Dewhurst done.
# Person David_Dodge done.
# Person David_Donohue done.
# Person David_Dorfman done.
# Person David_Duke done.
# Person David_Duval done.
# Person David_Eldon done.
# Person David_Gest done.
# Person David_Glenn done.
# Person David_Hannay done.
# Person David_Hanson done.
# Person David_Hasselhoff done.
# Person David_Heyman done.
# Person David_Heymann done.
# Person David_Hilt done.
# Person David_Ho done.
# Person David_Howard done.
# Person David_Hyde_Pierce done.
# Person David_Kelley done.
# Person David_Kelly done.
# Person David_Leahy done.
# Person David_McCallum done.
# Person David_McCullough done.
# Person David_McKiernan done.
# Person David_Millar done.
# Person David_Modell done.
# Person David_Montoya done.
# Person David_Myers done.
# Person David_Nalbandian done.
# Person David_Obey done.
# Person David_Oh done.
# Person David_Provost done.
# Person David_Przybyszewski done.
# Person David_Rivkin_Jr done.
# Person David_Scott_Morris done.
# Person David_Shayler done.
# Person David_Sibleyk done.
# Person David_Siegel done.
# Person David_Sousa done.
# Person David_Spade done.
# Person David_Stern done.
# Person David_Suazo done.
# Person David_Surrett done.
# Person David_Tornberg done.
# Person David_Trimble done.
# Person David_Welch done.
# Person David_Wells done.
# Person David_Westerfield done.
# Person David_Wolf done.
# Person David_Zeplowitz done.
# Person Davis_Love_III done.
# Person Dawna_LoPiccolo done.
# Person Dawn_Staley done.
# Person Dean_Barker done.
# Person Dean_Barkley done.
# Person Dean_Jacek done.
# Person Dean_Sheremet done.
# Person Debbie_Allen done.
# Person Debbie_Reynolds done.
# Person Debra_Brown done.
# Person Debra_Messing done.
# Person Debra_Rose done.
# Person Debra_Shank done.
# Person Debra_Yang done.
# Person Deb_Santos done.
# Person Deece_Eckstein done.
# Person Deena_Burnett done.
# Person Deepa_Mehta done.
# Person Della_Clara done.
# Person Delphine_Chuillot done.
# Person Demetrin_Veal done.
# Person Demetrius_Ferraciu done.
# Person Demi_Moore done.
# Person Denise_Johnson done.
# Person Denise_Locke done.
# Person Denise_van_Outen done.
# Person Denis_Coderre done.
# Person Denis_Fassou-Nguesso done.
# Person Deniz_Baykal done.
# Person Dennis_Archer done.
# Person Dennis_Erickson done.
# Person Dennis_Franchione done.
# Person Dennis_Hastert done.
# Person Dennis_Johnson done.
# Person Dennis_Kozlowski done.
# Person Dennis_Kucinich done.
# Person Dennis_Miller done.
# Person Dennis_Oswald done.
# Person Dennis_Powell done.
# Person Denys_Arcand done.
# Person Denzel_Washington done.
# Person Dereck_Whittenburg done.
# Person Derek_Abney done.
# Person Derek_Bond done.
# Person Derek_Jeter done.
# Person Derek_King done.
# Person Derek_Lowe done.
# Person Derek_Parra done.
# Person Derian_Hatcher done.
# Person Derrick_Battie done.
# Person Derrick_Rodgers done.
# Person Derrick_Taylor done.
# Person Desiree_Lemosi done.
# Person Desiree_McKenzie done.
# Person Desmon_Farmer done.
# Person Des_Brown done.
# Person Devin_Harris done.
# Person Dewayne_White done.
# Person Dexter_Jackson done.
# Person Diana_Krall done.
# Person Diana_Munz done.
# Person Diana_Renee_Valdivieso_Dubon done.
# Person Diana_Ross done.
# Person Diana_Silvius done.
# Person Diana_Taurasi done.
# Person Diana_Taylor done.
# Person Diane_Green done.
# Person Diane_Ladd done.
# Person Diane_Lane done.
# Person Dianne_Feinstein done.
# Person Dianne_Reeves done.
# Person Dick_Armey done.
# Person Dick_Bennett done.
# Person Dick_Cheney done.
# Person Dick_Clark done.
# Person Dick_Devine done.
# Person Dick_Jauron done.
# Person Dick_Latessa done.
# Person Dick_Posthumus done.
# Person Dick_Smothers done.
# Person Dick_Vermeil done.
# Person Didier_Defago done.
# Person Diego_Armando_Maradona done.
# Person Diego_Colorado done.
# Person Diego_Diego_Lerman done.
# Person Dieter_Holzer done.
# Person Dieter_Zetsche done.
# Person Dimitar_Berbatov done.
# Person Dimitri_Perricos done.
# Person Dinah_Turner done.
# Person Dinora_Rosales done.
# Person Dino_de_Laurentis done.
# Person Dino_Risi done.
# Person Din_Samsudin done.
# Person Dionigi_Tettamanzi done.
# Person Dionne_Warwick done.
# Person Dionyssis_Georgiadis done.
# Person Dion_Glover done.
# Person Dirk_Kempthorne done.
# Person Dita_Von_Tesse done.
# Person Djabir_Said-Guerni done.
# Person Doc_Rivers done.
# Person Dolly_Parton done.
# Person Dolma_Tsering done.
# Person Dominick_Dunne done.
# Person Dominic_Monaghan done.
# Person Dominik_Garcia-Lorido done.
# Person Dominik_Hrbaty done.
# Person Dominique_de_Villepin done.
# Person Dominique_Perben done.
# Person Donald_Anderson done.
# Person Donald_Carty done.
# Person Donald_Evans done.
# Person Donald_Fehr done.
# Person Donald_Hays done.
# Person Donald_Keck done.
# Person Donald_Keyser done.
# Person Donald_Pettit done.
# Person Donald_Regan done.
# Person Donald_Rumsfeld done.
# Person Donald_Trump done.
# Person Donatella_Versace done.
# Person Donna_Barrera done.
# Person Donna_Brazile done.
# Person Donna_Morrissey done.
# Person Donna_Ralston done.
# Person Donna_Shalala done.
# Person Donna_Walker done.
# Person Donnie_Brennan done.
# Person Donny_Osmond done.
# Person Don_Boudria done.
# Person Don_Carcieri done.
# Person Don_Flanagan done.
# Person Don_Henley done.
# Person Don_Hewitt done.
# Person Don_King done.
# Person Don_Lake done.
# Person Don_Matthews done.
# Person Don_Meredith done.
# Person Don_Nickles done.
# Person Don_Siegelman done.
# Person Dora_Bakoyianni done.
# Person Doris_Roberts done.
# Person Doris_Schroeder done.
# Person Dorothy_Lamour done.
# Person Dorothy_Loudon done.
# Person Dorothy_Wilson done.
# Person Dorthy_Moxley done.
# Person Dot_Helms done.
# Person Douglas_Faneuil done.
# Person Douglas_Gansler done.
# Person Douglas_Meester done.
# Person Douglas_Paal done.
# Person Doug_Christie done.
# Person Doug_Collins done.
# Person Doug_Duncan done.
# Person Doug_Melvin done.
# Person Doug_Moe done.
# Person Doug_Racine done.
# Person Doug_Wilson done.
# Person Dragan_Covic done.
# Person Drew_Barrymore done.
# Person Drew_Bledsoe done.
# Person Drew_Gooden done.
# Person Duane_Barber done.
# Person Duane_Lee_Chapman done.
# Person Dudley_Rogers done.
# Person Dule_Hill done.
# Person Duncan_Fletcher done.
# Person Dunn_Lampton done.
# Person Dustan_Mohr done.
# Person Dustin_Brown done.
# Person Dustin_Hoffman done.
# Person Dusty_Baker done.
# Person Du_Qinglin done.
# Person Dwain_Kyles done.
# Person Dwayne_Johnson done.
# Person Dwayne_Wade done.
# Person Dwayne_Williams done.
# Person Dyab_Abou_Jahjah done.
# Person Dyana_Calub done.
# Person Earl_Campbell done.
# Person Earl_Counter done.
# Person Earl_Fritts done.
# Person Earl_Scruggs done.
# Person Eddie_Compass done.
# Person Eddie_Fenech_Adami done.
# Person Eddie_Jordan done.
# Person Eddie_Lewis done.
# Person Eddie_Lucio done.
# Person Eddie_Murray done.
# Person Eddie_Sutton done.
# Person Eddy_Hartenstein done.
# Person Eddy_Merckx done.
# Person Edgar_Savisaar done.
# Person Edie_Falco done.
# Person Edina_Batar done.
# Person Edith_Masai done.
# Person Edmund_Hillary done.
# Person Edmund_Stoiber done.
# Person Edouard_Michelin done.
# Person Eduardo_Chillida done.
# Person Eduardo_Duhalde done.
# Person Eduardo_Fischer done.
# Person Eduardo_Romero done.
# Person Eduard_Limonov done.
# Person Eduard_Shevardnadze done.
# Person Edward_Albee done.
# Person Edward_Arsenault done.
# Person Edward_Belvin done.
# Person Edward_Burns done.
# Person Edward_Egan done.
# Person Edward_Flynn done.
# Person Edward_Greenspan done.
# Person Edward_James_Olmos done.
# Person Edward_Johnson done.
# Person Edward_Kennedy done.
# Person Edward_Lohn done.
# Person Edward_Lu done.
# Person Edward_Norton done.
# Person Edward_Said done.
# Person Edward_Seaga done.
# Person Edwina_Currie done.
# Person Edwin_Edwards done.
# Person Ed_Book done.
# Person Ed_Case done.
# Person Ed_Mekertichian done.
# Person Ed_Rendell done.
# Person Ed_Rosenthal done.
# Person Ed_Smart done.
# Person Ed_Sullivan done.
# Person Ed_Wade done.
# Person Efrain_Rios_Montt done.
# Person Eglis_Yaima_Cruz done.
# Person Eileen_Coparropa done.
# Person Eileen_Spina done.
# Person Einars_Repse done.
# Person Ekaterina_Dmitriev done.
# Person Ekke_Hard_Forberg done.
# Person Eladio_Larez done.
# Person Elaine_Chao done.
# Person Elaine_Stritch done.
# Person Elena_Bereznaya done.
# Person Elena_Bovina done.
# Person Elena_Dementieva done.
# Person Elena_de_Chavez done.
# Person Elena_Likhovtseva done.
# Person Elena_Tihomirova done.
# Person Elgin_Baylor done.
# Person Eliane_Karp done.
# Person Elias_Attallah done.
# Person Elijah_Wood done.
# Person Elijan_Ingram done.
# Person Elinor_Caplan done.
# Person Elin_Nordegren done.
# Person Eliott_Spitzer done.
# Person Elisabeth_Schumacher done.
# Person Elisabeth_Welch done.
# Person Elisha_Cuthbert done.
# Person Elizabeth_Berkeley done.
# Person Elizabeth_Dole done.
# Person Elizabeth_Hill done.
# Person Elizabeth_Hurley done.
# Person Elizabeth_Pena done.
# Person Elizabeth_Regan done.
# Person Elizabeth_Shue done.
# Person Elizabeth_Smart done.
# Person Elizabeth_Taylor done.
# Person Eliza_Dushku done.
# Person Eliza_Manningham-Buller done.
# Person Eli_Broad done.
# Person Eli_Rosenbaum done.
# Person Eli_Stutsman done.
# Person Ellen_Barkin done.
# Person Ellen_DeGeneres done.
# Person Ellen_Engleman done.
# Person Ellen_MacArthur done.
# Person Ellen_Martin done.
# Person Ellen_Pompeo done.
# Person Ellen_Saracini done.
# Person Elliott_Mincberg done.
# Person Elmar_Brok done.
# Person Elodie_Bouchez done.
# Person Eloy_Gutierrez done.
# Person Elsa_Zylberstein done.
# Person Elton_John done.
# Person Elva_Hsiao done.
# Person Elvis_Costello done.
# Person Elvis_Presley done.
# Person Elvis_Stojko done.
# Person El_Hadji_Diouf done.
# Person Emanuel_Ginobili done.
# Person Emelie_Loit done.
# Person Emile_Lahoud done.
# Person Emilio_Azcarraga_Jean done.
# Person Emilio_Botin done.
# Person Emily_Mason done.
# Person Emily_Mortimer done.
# Person Emily_Robison done.
# Person Emily_Stevens done.
# Person Eminem done.
# Person Emmanuelle_Beart done.
# Person Emmanuelle_Jagodsinski done.
# Person Emmanuel_Filiberto done.
# Person Emmanuel_Milingo done.
# Person Emma_Nicholson done.
# Person Emma_Thompson done.
# Person Emma_Watson done.
# Person Emmit_Smith done.
# Person Emmy_Rossum done.
# Person Emyr_Jones_Parry done.
# Person Enola_Rice done.
# Person Enos_Slaughter done.
# Person Enrica_Fico done.
# Person Enrik_Vendt done.
# Person Enrique_Bolanos done.
# Person Enrique_Haroldo_Gorriaran_Merlo done.
# Person Enrique_Iglesias done.
# Person Enrique_Medina_Gomez done.
# Person Enrique_Oliu done.
# Person Erick_Barkley done.
# Person Eric_Bana done.
# Person Eric_Benet done.
# Person Eric_Christian_Olsen done.
# Person Eric_Clapton done.
# Person Eric_Daze done.
# Person Eric_Dubin done.
# Person Eric_Fehr done.
# Person Eric_Hinske done.
# Person Eric_Idle done.
# Person Eric_Lindros done.
# Person Eric_Lloyd done.
# Person Eric_Robert_Rudolph done.
# Person Eric_Rosser done.
# Person Eric_Ryan_Donnelly done.
# Person Eric_Schacht done.
# Person Eric_Shinseki done.
# Person Eric_Snow done.
# Person Eric_Staal done.
# Person Eric_Taino done.
# Person Eric_Vigouroux done.
# Person Eric_Wedge done.
# Person Erika_Christensen done.
# Person Erika_Harold done.
# Person Erika_Reyes done.
# Person Eriko_Tamura done.
# Person Erik_Morales done.
# Person Erin_Brockovich done.
# Person Erin_Hershey_Presley done.
# Person Erin_Runnion done.
# Person Ernesto_Zedillo done.
# Person Ernest_Hollings done.
# Person Ernie_Els done.
# Person Ernie_Eves done.
# Person Ernie_Fletcher done.
# Person Ernie_Grunfeld done.
# Person Ernie_Harwell done.
# Person Ernie_Preate done.
# Person Ernie_Stewart done.
# Person Erskine_Bowles done.
# Person Erwin_Abdullah done.
# Person Erwin_Mapasseng done.
# Person Esad_Landzo done.
# Person Esteban_Cordoba-Velazquez done.
# Person Estella_Warren done.
# Person Estelle_Morris done.
# Person Ester_Canadas done.
# Person Esther_Macklin done.
# Person Ethan_Hawke done.
# Person Etta_James done.
# Person Eugene_Melnyk done.
# Person Eugene_Teslovic done.
# Person Eunice_Barber done.
# Person Eurico_Guterres done.
# Person Evander_Holyfield done.
# Person Evan_Marriott done.
# Person Evan_Rachel_Wood done.
# Person Eva_Amurri done.
# Person Eva_Dimas done.
# Person Eva_Herzigova done.
# Person Eva_Marie_Saint done.
# Person Eva_Mendes done.
# Person Evelyn_Lauder done.
# Person Eve_Ensler done.
# Person Eve_Pelletier done.
# Person Evgeni_Plushenko done.
# Person Evie_Lazarou done.
# Person Evo_Morales done.
# Person Ewan_McGregor done.
# Person E_Clay_Shaw done.
# Person Fabian_Vargas done.
# Person Fabiola_Zuluaga done.
# Person Fabrice_Santoro done.
# Person Fabricio_Oberto done.
# Person Faisal_Iqbal done.
# Person Faisal_Saleh_Hayat done.
# Person Fann_Wong done.
# Person Farida_Ragoonanan done.
# Person Farouk_al-Sharaa done.
# Person Farouk_Kaddoumi done.
# Person Fatma_Kusibeh done.
# Person Fatmir_Limaj done.
# Person Faye_Alibocus done.
# Person Faye_Dunaway done.
# Person Faye_Wong done.
# Person Fayssal_Mekdad done.
# Person Fazal-ur-Rehman done.
# Person Federico_Castelan_Sayre done.
# Person Federico_Fellini done.
# Person Federico_Trillo done.
# Person Feliciano_Lopez done.
# Person Felicity_Huffman done.
# Person Felipe_De_Borbon done.
# Person Felipe_Fernandez done.
# Person Felipe_Perez_Roque done.
# Person Felix_Doh done.
# Person Felix_Mantilla done.
# Person Felix_Sanchez done.
# Person Felix_Trinidad done.
# Person Ferenc_Madl done.
# Person Fernando_Alonso done.
# Person Fernando_Gonzalez done.
# Person Fernando_Henrique_Cardoso done.
# Person Fernando_Hierro done.
# Person Fernando_Leon_de_Aranoa done.
# Person Fernando_Sanz done.
# Person Fernando_Valenzuela done.
# Person Fernando_Vargas done.
# Person Fernando_Velardez done.
# Person Festus_Mogae done.
# Person Fidel_Castro done.
# Person Fidel_Castro_Daiz-Balart done.
# Person Filippo_Inzaghi done.
# Person Filippo_Volandri done.
# Person Filip_De_Winter done.
# Person Fiona_Milne done.
# Person Flavia_Delaroli done.
# Person Flavia_Pennetta done.
# Person Florecita_Cobian done.
# Person Florencia_Kirchner done.
# Person Florencia_Macri done.
# Person Flor_Montulo done.
# Person Floyd_Keith done.
# Person Floyd_Mayweather done.
# Person Francesco_Totti done.
# Person Frances_Fisher done.
# Person Francisco_Flores done.
# Person Francisco_Garcia done.
# Person Francisco_Maturana done.
# Person Francisco_Santos done.
# Person Francisco_Urenda done.
# Person Francis_Collins done.
# Person Francis_Crick done.
# Person Francis_Ford_Coppola done.
# Person Francis_George done.
# Person Francis_Mer done.
# Person Francis_Ricciardone done.
# Person Franck_Cerutti done.
# Person Francois_Botha done.
# Person Francois_Ozon done.
# Person Francois_Pienaar done.
# Person Franco_Cangele done.
# Person Franco_Dragone done.
# Person Franco_Frattini done.
# Person Franklin_Brown done.
# Person Franklin_Damann done.
# Person Franko_Simatovic done.
# Person Frank_Abagnale_Jr done.
# Person Frank_Beamer done.
# Person Frank_Bell done.
# Person Frank_Cassell done.
# Person Frank_Coraci done.
# Person Frank_Dunham_Jr done.
# Person Frank_Griswold done.
# Person Frank_Hilldrup done.
# Person Frank_Hsieh done.
# Person Frank_Keating done.
# Person Frank_Lautenberg done.
# Person Frank_Marshall done.
# Person Frank_Murkowski done.
# Person Frank_Pallone done.
# Person Frank_Schmoekel done.
# Person Frank_Shea done.
# Person Frank_Sinatra done.
# Person Frank_Solich done.
# Person Frank_Stallone done.
# Person Frank_Taylor done.
# Person Frank_Van_Ecke done.
# Person Frank_Wycheck done.
# Person Frank_Zappa done.
# Person Franz_Beckenbauer done.
# Person Franz_Fischler done.
# Person Franz_Gsell done.
# Person Franz_Muentefering done.
# Person Fran_Drescher done.
# Person Freda_Black done.
# Person Freddy_Garcia done.
# Person Freddy_Vasques_Kinchokpe done.
# Person Frederick_Madden done.
# Person Frederique_van_der_Wal done.
# Person Fredric_Seaman done.
# Person Fred_Durst done.
# Person Fred_Eckhard done.
# Person Fred_Funk done.
# Person Fred_Huff done.
# Person Fred_Rogers done.
# Person Fred_Swan done.
# Person Fred_Thompson done.
# Person Fred_Wilpon done.
# Person Fruit_Chan done.
# Person Fujio_Cho done.
# Person Fujio_Mitarai done.
# Person Gabi_Zimmer done.
# Person Gabriella_Bo done.
# Person Gabrielle_Rose done.
# Person Gabrielle_Union done.
# Person Gabriel_Batistuta done.
# Person Gabriel_Farhi done.
# Person Gabriel_Hughes done.
# Person Gabriel_Jorge_Ferreia done.
# Person Gabriel_Valdes done.
# Person Gael_Garcia_Bermal done.
# Person Gala_Leon_Garcia done.
# Person Galen_Rowell done.
# Person Gao_Qiang done.
# Person Garry_Alejano done.
# Person Garry_Kasparov done.
# Person Garry_McCoy done.
# Person Garry_Trudeau done.
# Person Garry_Witherall done.
# Person Garth_Drabinsky done.
# Person Gary_Bald done.
# Person Gary_Barnett done.
# Person Gary_Bauer done.
# Person Gary_Bergeron done.
# Person Gary_Bettman done.
# Person Gary_Carter done.
# Person Gary_Coleman done.
# Person Gary_Condit done.
# Person Gary_Dellaverson done.
# Person Gary_Doer done.
# Person Gary_Forsee done.
# Person Gary_Gero done.
# Person Gary_Gitnick done.
# Person Gary_Leon_Ridgway done.
# Person Gary_Locke done.
# Person Gary_Marshall done.
# Person Gary_Paer done.
# Person Gary_Sayler done.
# Person Gary_Sinise done.
# Person Gary_Stevens done.
# Person Gary_Williams done.
# Person Gary_Winnick done.
# Person Gaston_Gaudio done.
# Person Gavin_Degraw done.
# Person Gavyn_Arthur done.
# Person Gavyn_Davies done.
# Person Gene_Autry done.
# Person Gene_Hackman done.
# Person Gene_Keady done.
# Person Gene_Orza done.
# Person Gene_Robinson done.
# Person Gene_Sauers done.
# Person Gennifer_Flowers done.
# Person Geno_Auriemma done.
# Person Gen_Meredith done.
# Person Geoffrey_Davis done.
# Person Geoffrey_Rush done.
# Person Geoff_Dixon done.
# Person Geoff_Hoon done.
# Person George_Allen done.
# Person George_Blaney done.
# Person George_Bovell done.
# Person George_Brumley done.
# ...
# Person Ian_Thorpe done.
# Person Ian_Wilmut done.
# Person Iban_Mayo done.
# Person Ibrahim_Al-Marashi done.
# Person Ibrahim_Haddad done.
# Person Ibrahim_Hilal done.
# Person Ibrahim_Jaafari done.
# Person Ibrahim_Rugova done.
# Person Idi_Amin done.
# Person Ignacio_Antonio_Velasco done.
# Person Ignatius_Wang done.
# Person Igor_Ivanov done.
# Person Igor_Trunov done.
# Person Ilan_Goldfajn done.
# Person Ilan_Ramon done.
# Person Ilham_Aliev done.
# Person Ilie_Nastase done.
# Person Imad_Khadduri done.
# Person Imad_Moustapha done.
# Person Imam_Samudra done.
# Person Imelda_Marcos done.
# Person Imran_Khan done.
# Person Imre_Kertasz done.
# Person Inam-ul-Haq done.
# Person Infanta_Cristina done.
# Person Inga_Hall done.
# Person Ingrid_Betancourt done.
# Person Inocencio_Arias done.
# Person Intisar_Ajouri done.
# Person Ion_Iliescu done.
# Person Ion_Tiriac done.
# Person Iran_Brown done.
# Person Ira_Einhorn done.
# Person Irene_Kahn done.
# Person Irfan_Ahmed done.
# Person Irina_Framtsova done.
# Person Irina_Lobacheva done.
# Person Irina_Yatchenko done.
# Person Irv_Nathan done.
# Person Irwan_Fadzi_Idris done.
# Person Isabela_Moraes done.
# Person Isabella_Rossellini done.
# Person Isabelle_Huppert done.
# Person Isabel_Orellana done.
# Person Isaiah_Washington done.
# Person Ishaq_Shahryar done.
# Person Isidro_Pastor done.
# Person Islam_Karimov done.
# Person Ismael_Miranda done.
# Person Ismail_Abu_Shanab done.
# Person Ismail_Cem done.
# Person Ismail_Khan done.
# Person Ismail_Merchant done.
# Person Itamar_Franco done.
# Person Itzhak_Perlman done.
# Person Ivana_Trump done.
# Person Ivan_Helguera done.
# Person Ivan_Lee done.
# Person Ivan_Shvedoff done.
# Person Ivan_Stambolic done.
# Person Iva_Majoli done.
# Person Iveta_Benesova done.
# Person Ivo_Dubs done.
# Person Izzat_Ibrahim done.
# Person Jaap_de_Hoop_Scheffer done.
# Person Jackie_Chan done.
# Person Jackie_Dennis done.
# Person Jackie_Sherrill done.
# Person Jacky_Cheung done.
# Person Jack_Goodman done.
# Person Jack_Grubman done.
# Person Jack_Knowlton done.
# Person Jack_LaLanne done.
# Person Jack_Nicholson done.
# Person Jack_Osbourne done.
# Person Jack_Smith done.
# Person Jack_Straw done.
# Person Jack_Valenti done.
# Person Jack_Welch done.
# Person Jacob_Frenkel done.
# Person Jacqueline_Edwards done.
# Person Jacqueline_Gold done.
# Person Jacqueline_Marris done.
# Person Jacqueline_Obradors done.
# Person Jacques_Chirac done.
# Person Jacques_Kallis done.
# Person Jacques_Rogge done.
# Person Jacques_Villeneuve done.
# Person Jada_Pinkett_Smith done.
# Person Jade_Jagger done.
# Person Jafar_Umar_Thalib done.
# Person Jaime_Orti done.
# Person Jaime_Pressly done.
# Person Jake_Brace done.
# Person Jake_Gyllenhaal done.
# Person Jake_Plummer done.
# Person Jakob_Kellenberger done.
# Person Jalal_Talabani done.
# Person Jalen_Rose done.
# Person James_Baker done.
# Person James_Ballenger done.
# Person James_Barksdale done.
# Person James_Becker done.
# Person James_Blake done.
# Person James_Brazelton done.
# Person James_Brosnahan done.
# Person James_Brown done.
# Person James_Butts done.
# Person James_Caan done.
# Person James_Cameron done.
# Person James_Carville done.
# Person James_Coburn done.
# Person James_Collinson done.
# Person James_Comey done.
# Person James_Coviello done.
# Person James_Cunningham done.
# Person James_Dingemans done.
# Person James_Franco done.
# Person James_Gandolfini done.
# Person James_Gibson done.
# Person James_Hakett done.
# Person James_Hallock done.
# Person James_Harris done.
# Person James_Hill done.
# Person James_Hoffa done.
# Person James_Hughes done.
# Person James_Ivory done.
# Person James_Jones done.
# Person James_Kelly done.
# Person James_Kirtley done.
# Person James_Kopp done.
# Person James_Layug done.
# Person James_Lockhart done.
# Person James_Maguire done.
# Person James_Mathis done.
# Person James_May done.
# Person James_McGreevey done.
# Person James_McMahon done.
# Person James_McPherson done.
# Person James_Meeks done.
# Person James_Meredeth done.
# Person James_Morris done.
# Person James_Murdoch done.
# Person James_Parker done.
# Person James_Phelps done.
# Person James_Roberts done.
# Person James_Robertson_Jr done.
# Person James_Schultz done.
# Person James_Sensenbrenner done.
# Person James_Smith done.
# Person James_Spalding done.
# Person James_Traficant done.
# Person James_Wallack done.
# Person James_Watt done.
# Person James_Wattana done.
# Person James_Williams done.
# Person James_Wolfensohn done.
# Person James_W_Kennedy done.
# Person James_Young done.
# Person Jamie_Carey done.
# Person Jamie_Cooke done.
# Person Jamie_Dimon done.
# Person Jamie_Kellner done.
# Person Jamie_King done.
# Person Jamie_Lee_Curtis done.
# Person Jamie_Martin done.
# Person Jamie_Olis done.
# Person Jamie_Villafane done.
# Person Jamir_Miller done.
# Person Jamling_Norgay done.
# Person Jan-Michael_Gambill done.
# Person Jana_Henke done.
# Person Jana_Pittman done.
# Person Janela_Jara done.
# Person Janette_Husarova done.
# Person Janet_Chandler done.
# Person Janet_Crawford done.
# Person Janet_Ecker done.
# Person Janet_Horvath done.
# Person Janet_Leigh done.
# Person Janet_Napolitano done.
# Person Janet_Thorpe done.
# Person Janez_Drnovsek done.
# Person Jane_Clayson done.
# Person Jane_Fonda done.
# Person Jane_Kaczmarek done.
# Person Jane_Krakowski done.
# Person Jane_Leeves done.
# Person Jane_Menelaus done.
# Person Jane_Pauley done.
# Person Jane_Riley done.
# Person Jane_Rooney done.
# Person Jane_Russell done.
# Person Jane_Walker_Wood done.
# Person Janica_Kostelic done.
# Person Janice_Abreu done.
# Person Janice_Goldfinger done.
# Person Janine_Pietsch done.
# Person Janis_Ruth_Coulter done.
# Person Janusz_Kaminski done.
# Person Jan_Bjoerklund done.
# Person Jan_De_Bont done.
# Person Jan_Paul_Miller done.
# Person Jan_Petersen done.
# Person Jan_Peter_Balkenende done.
# Person Jan_Pronk done.
# Person Jan_Ullrich done.
# Person Jan_van_Breda_Kolff done.
# Person Jaouad_Gharib done.
# Person Jaqueline_Godoy done.
# Person Jaromir_Jagr done.
# Person Jason_Alexander done.
# Person Jason_Bentley done.
# Person Jason_Biggs done.
# Person Jason_Campbell done.
# Person Jason_Clermont done.
# Person Jason_Gardner done.
# Person Jason_Jennings done.
# Person Jason_Kapono done.
# Person Jason_Keep done.
# Person Jason_Kidd done.
# Person Jason_Lezak done.
# Person Jason_Mewes done.
# Person Jason_Petty done.
# Person Jason_Priestley done.
# Person Jason_Sehorn done.
# Person Jason_Sorens done.
# Person Jason_Statham done.
# Person Jason_Vale done.
# Person Jason_White done.
# Person Javier_Bardem done.
# Person Javier_Camara done.
# Person Javier_Delgado done.
# Person Javier_Saviola done.
# Person Javier_Solana done.
# Person Javier_Vargas done.
# Person Javier_Vazquez done.
# Person Javier_Weber done.
# Person Javier_Zanetti done.
# Person Jawad_Boulus done.
# Person Jaymon_Crabb done.
# Person Jayne_Yarris done.
# Person Jayson_Williams done.
# Person Jay_Garner done.
# Person Jay_Leno done.
# Person Jay_Rasulo done.
# Person JC_Chasez done.
# Person Jean-Claude_Braquet done.
# Person Jean-Claude_Juncker done.
# Person Jean-Claude_Trichet done.
# Person Jean-Claude_Van_Damme done.
# Person Jean-David_Levitte done.
# Person Jean-Francois_Lemounier done.
# Person Jean-Francois_Pontal done.
# Person Jean-Luc_Bideau done.
# Person Jean-Marc_de_La_Sabliere done.
# Person Jean-Marc_Olive done.
# Person Jean-Patrick_Nazon done.
# Person Jean-Pierre_Bemba done.
# Person Jean-Pierre_Raffarin done.
# Person Jean-Rene_Fourtou done.
# Person Jean-Sebastien_Giguere done.
# Person Jeanette_Gray done.
# Person Jeanette_Stauffer done.
# Person Jeane_Kirkpatrick done.
# Person Jeannette_Biedermann done.
# Person Jeanne_Anne_Schroeder done.
# Person Jeanne_Moreau done.
# Person Jean_Brumley done.
# Person Jean_Carnahan done.
# Person Jean_Charest done.
# Person Jean_Chretien done.
# Person Jean_Nagel done.
# Person Jean_Todt done.
# Person Jeb_Bush done.
# Person Jefferson_Perez done.
# Person Jeffery_Hendren done.
# Person Jeffery_Strelzin done.
# Person Jeffrey_Archer done.
# Person Jeffrey_Ashby done.
# Person Jeffrey_Donaldson done.
# Person Jeffrey_Immelt done.
# Person Jeffrey_Jones done.
# Person Jeffrey_Katzenberg done.
# Person Jeffrey_Pfeffer done.
# Person Jeffrey_Scott_Postell done.
# Person Jeff_Bridges done.
# Person Jeff_Bzdelik done.
# Person Jeff_Dederian done.
# Person Jeff_Feldman done.
# Person Jeff_George done.
# Person Jeff_Hornacek done.
# Person Jeff_Roehm done.
# Person Jeff_Schiffner done.
# Person Jeff_Van_Gundy done.
# Person Jeff_Weaver done.
# Person Jelena_Dokic done.
# Person Jenna_Elfman done.
# Person Jennette_Bradley done.
# Person Jennie_Finch done.
# Person Jennie_Garth done.
# Person Jennifer_Aniston done.
# Person Jennifer_Capriati done.
# Person Jennifer_Connelly done.
# Person Jennifer_Furminger done.
# Person Jennifer_Garner done.
# Person Jennifer_Granholm done.
# Person Jennifer_Gratz done.
# Person Jennifer_Keller done.
# Person Jennifer_Lopez done.
# Person Jennifer_Love_Hewitt done.
# Person Jennifer_McCoy done.
# Person Jennifer_Murray done.
# Person Jennifer_Pena done.
# Person Jennifer_Reilly done.
# Person Jennifer_Renee_Short done.
# Person Jennifer_Rodriguez done.
# Person Jennifer_Thompson done.
# Person Jennifer_Tilly done.
# Person Jenny_Romero done.
# Person Jens_Lehmann done.
# Person Jen_Bice done.
# Person Jen_Schefft done.
# Person Jeong_Se-hyun done.
# Person Jerelle_Kraus done.
# Person Jeremy_Fogel done.
# Person Jeremy_Gompertz done.
# Person Jeremy_Greenstock done.
# Person Jeremy_Shockey done.
# Person Jeremy_Wotherspoon done.
# Person Jeri_Ryan done.
# Person Jerome_Golmard done.
# Person Jerome_Jenkins done.
# Person Jerry_Angelo done.
# Person Jerry_Bruckheimer done.
# Person Jerry_Colangelo done.
# Person Jerry_Falwell done.
# Person Jerry_Hall done.
# Person Jerry_Jones done.
# Person Jerry_Lewis done.
# Person Jerry_McEntee done.
# Person Jerry_Oliver done.
# Person Jerry_Pauley done.
# Person Jerry_Regier done.
# Person Jerry_Rice done.
# Person Jerry_Seinfeld done.
# Person Jerry_Sexton done.
# Person Jerry_Sloan done.
# Person Jerry_Springer done.
# Person Jerry_Tarkanian done.
# Person Jesper_Parnevik done.
# Person Jesse_Harris done.
# Person Jesse_Helms done.
# Person Jesse_Jackson done.
# Person Jesse_James done.
# Person Jesse_James_Leija done.
# Person Jesse_Ventura done.
# Person Jessica_Alba done.
# Person Jessica_Biel done.
# Person Jessica_Brungo done.
# Person Jessica_Capshaw done.
# Person Jessica_Lange done.
# Person Jessica_Lynch done.
# Person Jessica_Simpson done.
# Person Jesus_Cardenal done.
# Person Jewel_Howard-Taylor done.
# Person Jiang_Zemin done.
# Person Jia_Qinglin done.
# Person Jimmy_Carter done.
# Person Jimmy_Gobble done.
# Person Jimmy_Gurule done.
# Person Jimmy_Iovine done.
# Person Jimmy_Jimenez done.
# Person Jimmy_Kimmel done.
# Person Jimmy_Lee done.
# Person Jimmy_Smits done.
# Person Jimmy_Szymanski done.
# Person Jim_Abbott done.
# Person Jim_Ahern done.
# Person Jim_Anderson done.
# Person Jim_Beattie done.
# Person Jim_Bollman done.
# Person Jim_Bunning done.
# Person Jim_Calhoun done.
# Person Jim_Cantalupo done.
# Person Jim_Carrey done.
# Person Jim_Doyle done.
# Person Jim_Edmonds done.
# Person Jim_Fassel done.
# Person Jim_Flaherty done.
# Person Jim_Freudenberg done.
# Person Jim_Furyk done.
# Person Jim_Greenwood done.
# Person Jim_Hahn done.
# Person Jim_Hardin done.
# Person Jim_Harrick done.
# Person Jim_Haslett done.
# Person Jim_Hendry done.
# Person Jim_Jeffords done.
# Person Jim_Kelly done.
# Person Jim_Leach done.
# Person Jim_Letten done.
# Person Jim_Nochols done.
# Person Jim_OBrien done.
# Person Jim_Otto done.
# Person Jim_Parque done.
# Person Jim_Paxson done.
# Person Jim_Piper done.
# Person Jim_Ryan done.
# Person Jim_Schwarz done.
# Person Jim_Spinoza done.
# Person Jim_Sterk done.
# Person Jim_Talent done.
# Person Jim_Taylor done.
# Person Jim_Thome done.
# Person Jim_Tressel done.
# Person Jim_Wall done.
# Person Jim_Wessling done.
# Person Jim_Wong done.
# Person Jim_Zorn done.
# Person Jiri_Novak done.
# Person JJ_Redick done.
# Person JK_Rowling done.
# Person Joanna_Poitier done.
# Person Joanne_Duquette done.
# Person Joanne_Woodward done.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-1945ec1d1edb> in <module>()
#       1 names = get_person_list(database_path)
# ----> 2 load_people_faces(database_path, names, save_path)
#
# <ipython-input-45-6e477dd7e551> in load_people_faces(dir_path, person_paths, save_file)
#      46         full_path = dir_path + '/' + person_path
#      47         #print(full_path, flush=True)
# ---> 48         reps, file_names = reps_for_person(full_path)
#      49         #print(len(reps), flush=True)
#      50         print('Person ' + person_path + ' done.', flush=True)
#
# <ipython-input-45-6e477dd7e551> in reps_for_person(dir_name)
#      19
#      20     for fname in os.listdir(dir_name):
# ---> 21         rep = rep_for_image_path(session, dir_name + '/' + fname)
#      22         if rep is not None:
#      23             all.append(rep[0])
#
# <ipython-input-45-6e477dd7e551> in rep_for_image_path(session, image_path)
#       2     global image_batch, phase_train_placeholder, embeddings
#       3
# ----> 4     rects, face_orig = detect_face_mtcnn(image_path)
#       5     if len(rects) > 0:
#       6         face = align_face(face_orig, rects[0])
#
# <ipython-input-39-c1c9661100ee> in detect_face_mtcnn(image_path)
#       2     img = mpimg.imread(image_path)
#       3     img = img[:,:,0:3]
# ----> 4     bbs, lms = detect_face.detect_face(img, minsize, pnet, rnet, onet, threshold, factor)
#       5     boxes = []
#       6     landmarks = []
#
# C:\Users\Fabian\Studium\02Master\Semester 3\Roboy\Vision\models\mtcnn\detect_face.py in detect_face(img, minsize, pnet, rnet, onet, threshold, factor)
#     326         img_x = np.expand_dims(im_data, 0)
#     327         img_y = np.transpose(img_x, (0,2,1,3))
# --> 328         out = pnet(img_y)
#     329         out0 = np.transpose(out[0], (0,2,1,3))
#     330         out1 = np.transpose(out[1], (0,2,1,3))
#
# C:\Users\Fabian\Studium\02Master\Semester 3\Roboy\Vision\models\mtcnn\detect_face.py in <lambda>(img)
#     291         onet.load(os.path.join(model_path, 'det3.npy'), sess)
#     292
# --> 293     pnet_fun = lambda img : sess.run(('pnet/conv4-2/BiasAdd:0', 'pnet/prob1:0'), feed_dict={'pnet/input:0':img})
#     294     rnet_fun = lambda img : sess.run(('rnet/conv5-2/conv5-2:0', 'rnet/prob1:0'), feed_dict={'rnet/input:0':img})
#     295     onet_fun = lambda img : sess.run(('onet/conv6-2/conv6-2:0', 'onet/conv6-3/conv6-3:0', 'onet/prob1:0'), feed_dict={'onet/input:0':img})
#
# C:\Users\Fabian\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Users\Fabian\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# C:\Users\Fabian\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Users\Fabian\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# C:\Users\Fabian\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Load calculated embeddings

# %% [markdown]
# Loading pre-calculated embeddings on lfw:

# %%
names = np.load('../models/lfw_embeddings/facenet_names.npy')
people_reps = np.load('../models/lfw_embeddings/facenet_reps.npy')
